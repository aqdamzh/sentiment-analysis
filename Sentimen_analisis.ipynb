# %%
# Import Library

# %%
# !pip install google-play-scraper
# !pip install wordcloud

 
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all
 
import pandas as pd  # Pandas untuk manipulasi dan analisis data
pd.options.mode.chained_assignment = None  # Menonaktifkan peringatan chaining
import numpy as np  # NumPy untuk komputasi numerik
seed = 0
np.random.seed(seed)  # Mengatur seed untuk reproduktibilitas
import matplotlib.pyplot as plt  # Matplotlib untuk visualisasi data
import seaborn as sns  # Seaborn untuk visualisasi data statistik, mengatur gaya visualisasi
from sklearn.metrics import accuracy_score
 
import datetime as dt  # Manipulasi data waktu dan tanggal
import re  # Modul untuk bekerja dengan ekspresi reguler
import string  # Berisi konstanta string, seperti tanda baca
from nltk.tokenize import word_tokenize  # Tokenisasi teks
from nltk.corpus import stopwords  # Daftar kata-kata berhenti dalam teks
 
# !pip install sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory  # Stemming (penghilangan imbuhan kata) dalam bahasa Indonesia
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory  # Menghapus kata-kata berhenti dalam bahasa Indonesia
 
from wordcloud import WordCloud  # Membuat visualisasi berbentuk awan kata (word cloud) dari teks
 
import nltk  # Import pustaka NLTK (Natural Language Toolkit).
nltk.download('punkt')  # Mengunduh dataset yang diperlukan untuk tokenisasi teks.
nltk.download('stopwords')  # Mengunduh dataset yang berisi daftar kata-kata berhenti (stopwords) dalam berbagai bahasa.
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-play-scraper in c:\users\admin.desktop-qgh4vss.000\appdata\roaming\python\python312\site-packages (1.2.7)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\admin.desktop-qgh4vss.000\appdata\roaming\python\python312\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Sastrawi in c:\users\admin.desktop-qgh4vss.000\appdata\roaming\python\python312\site-packages (1.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sastrawi in c:\users\admin.desktop-qgh4vss.000\appdata\roaming\python\python312\site-packages (1.0.1)
# [nltk_data] Downloading package punkt to C:\Users\admin.DESKTOP-
# [nltk_data]     QGH4VSS.000\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\admin.DESKTOP-
# [nltk_data]     QGH4VSS.000\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Scraping Dataset

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews_all, Sort
 
# Mengambil semua ulasan dari aplikasi dengan ID 'com.byu.id' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews_all(
    'com.byu.id',          # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=1000             # Jumlah maksimum ulasan yang ingin diambil
)

# %%
# Menyimpan ulasan dalam file CSV
import csv
 
with open('ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
# Loading Dataset

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)
 
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)
 
# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  7a685162-dcbc-4e73-a85a-b76ff20b6aef  Pengguna Google
# 1  73582569-46d5-4970-91a4-e3f8bbd3414f  Pengguna Google
# 2  eaf2ea33-285b-4bf8-b350-e6e282cc3087  Pengguna Google
# 3  6bb6a348-d92f-4bda-92b5-ddedcbbe5f6a  Pengguna Google
# 4  c40a15e6-004c-455c-a14f-217579fe0c07  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Awal pemakaian tidak ada gangguan tapi makin s...      3             26
# 1  Jaringan suka ilang,harus bolak balik mode pes...      1            190
# 2  Harga paket paling ramah di kantong dibanding ...      5            106
# 3  Kalau di bilang jaringannya mantap tapi agak n...      4              0
# 4  Kacau makin parah!!!, udah sering komplain jug...      1             52
#
#   reviewCreatedVersion                  at  \
# 0               1.59.0 2024-11-27 11:42:00
# 1               1.59.0 2024-11-27 22:27:49
# 2               1.59.0 2024-11-28 21:30:02
# 3               1.59.0 2024-12-02 18:31:36
# 4               1.59.0 2024-11-29 19:21:15
#
#                                         replyContent           repliedAt  \
# 0  Dear, Kak Fazil. Maafin banget jadi bikin kamu... 2024-11-28 02:02:37
# 1  Hallo Kak Feri, maafin udah bikin ga nyaman. B... 2024-11-28 04:23:03
# 2  Halo, Kak Mahmud. Makasih banyak buat semua sa... 2024-11-29 08:08:26
# 3  Hi Kak, Makasih banyak ya buat feedback-nya, s... 2024-12-03 04:35:39
# 4  Hi, Kak. Maaf banget udah bikin ga nyaman. Unt... 2024-11-30 05:26:26
#
#   appVersion
# 0     1.59.0
# 1     1.59.0
# 2     1.59.0
# 3     1.59.0
# 4     1.59.0

# %%
# Menampilkan informasi tentang DataFrame app_reviews_df
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121500 entries, 0 to 121499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              121500 non-null  object
#  1   userName              121500 non-null  object
#  2   userImage             121500 non-null  object
#  3   content               121499 non-null  object
#  4   score                 121500 non-null  int64
#  5   thumbsUpCount         121500 non-null  int64
#  6   reviewCreatedVersion  103686 non-null  object
#  7   at                    121500 non-null  datetime64[ns]
#  8   replyContent          112711 non-null  object
#  9   repliedAt             112711 non-null  datetime64[ns]
#  10  appVersion            103686 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 10.2+ MB

# %%
# Membuat DataFrame baru (clean_df) dengan menghapus baris yang memiliki nilai yang hilang (NaN) dari app_reviews_df
clean_df = app_reviews_df.dropna()

# %%
# Menghapus baris duplikat dari DataFrame clean_df
clean_df = clean_df.drop_duplicates()
 
# Menghitung jumlah baris dan kolom dalam DataFrame clean_df setelah menghapus duplikat
jumlah_ulasan_setelah_hapus_duplikat, jumlah_kolom_setelah_hapus_duplikat = clean_df.shape

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95889 entries, 0 to 121498
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              95889 non-null  object
#  1   userName              95889 non-null  object
#  2   userImage             95889 non-null  object
#  3   content               95889 non-null  object
#  4   score                 95889 non-null  int64
#  5   thumbsUpCount         95889 non-null  int64
#  6   reviewCreatedVersion  95889 non-null  object
#  7   at                    95889 non-null  datetime64[ns]
#  8   replyContent          95889 non-null  object
#  9   repliedAt             95889 non-null  datetime64[ns]
#  10  appVersion            95889 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 8.8+ MB

# %%
# !pip install Sastrawi
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer import StemmerFactory
 
def cleaningText(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text) # menghapus mention
    text = re.sub(r'#[A-Za-z0-9]+', '', text) # menghapus hashtag
    text = re.sub(r'RT[\s]', '', text) # menghapus RT
    text = re.sub(r"http\S+", '', text) # menghapus link
    text = re.sub(r'[0-9]+', '', text) # menghapus angka
    text = re.sub(r'[^\w\s]', '', text) # menghapus karakter selain huruf dan angka
 
    text = text.replace('\n', ' ') # mengganti baris baru dengan spasi
    text = text.translate(str.maketrans('', '', string.punctuation)) # menghapus semua tanda baca
    text = text.strip(' ') # menghapus karakter spasi dari kiri dan kanan teks
    return text
 
def casefoldingText(text): # Mengubah semua karakter dalam teks menjadi huruf kecil
    text = text.lower()
    return text
 
def tokenizingText(text): # Memecah atau membagi string, teks menjadi daftar token
    text = word_tokenize(text)
    return text
 
def filteringText(text): # Menghapus stopwords dalam teks
    listStopwords = set(stopwords.words('indonesian'))
    listStopwords1 = set(stopwords.words('english'))
    listStopwords.update(listStopwords1)
    listStopwords.update(['iya','yaa','gak','nya','na','sih','ku',"di","ga","ya","gaa","loh","kah","woi","woii","woy"])
    filtered = []
    for txt in text:
        if txt not in listStopwords:
            filtered.append(txt)
    text = filtered
    return text
 
def stemmingText(text): # Mengurangi kata ke bentuk dasarnya yang menghilangkan imbuhan awalan dan akhiran atau ke akar kata
    # Membuat objek stemmer
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
 
    # Memecah teks menjadi daftar kata
    words = text.split()
 
    # Menerapkan stemming pada setiap kata dalam daftar
    stemmed_words = [stemmer.stem(word) for word in words]
 
    # Menggabungkan kata-kata yang telah distem
    stemmed_text = ' '.join(stemmed_words)
 
    return stemmed_text
 
def toSentence(list_words): # Mengubah daftar kata menjadi kalimat
    sentence = ' '.join(word for word in list_words)
    return sentence
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Sastrawi in c:\users\admin.desktop-qgh4vss.000\appdata\roaming\python\python312\site-packages (1.0.1)

# %%
slangwords = {"@": "di", "abis": "habis", "wtb": "beli", "masi": "masih", "wts": "jual", "wtt": "tukar", "bgt": "banget", "maks": "maksimal" }
def fix_slangwords(text):
    words = text.split()
    fixed_words = []
 
    for word in words:
        if word.lower() in slangwords:
            fixed_words.append(slangwords[word.lower()])
        else:
            fixed_words.append(word)
 
    fixed_text = ' '.join(fixed_words)
    return fixed_text

# %%
# Membersihkan teks dan menyimpannya di kolom 'text_clean'
clean_df['text_clean'] = clean_df['content'].apply(cleaningText)
 
# Mengubah huruf dalam teks menjadi huruf kecil dan menyimpannya di 'text_casefoldingText'
clean_df['text_casefoldingText'] = clean_df['text_clean'].apply(casefoldingText)
 
# Mengganti kata-kata slang dengan kata-kata standar dan menyimpannya di 'text_slangwords'
clean_df['text_slangwords'] = clean_df['text_casefoldingText'].apply(fix_slangwords)
 
# Memecah teks menjadi token (kata-kata) dan menyimpannya di 'text_tokenizingText'
clean_df['text_tokenizingText'] = clean_df['text_slangwords'].apply(tokenizingText)
 
# Menghapus kata-kata stop (kata-kata umum) dan menyimpannya di 'text_stopword'
clean_df['text_stopword'] = clean_df['text_tokenizingText'].apply(filteringText)
 
# Menggabungkan token-token menjadi kalimat dan menyimpannya di 'text_akhir'
clean_df['text_akhir'] = clean_df['text_stopword'].apply(toSentence)

# %%
clean_df
# Out:
#                                     reviewId         userName  \
# 0       7a685162-dcbc-4e73-a85a-b76ff20b6aef  Pengguna Google
# 1       73582569-46d5-4970-91a4-e3f8bbd3414f  Pengguna Google
# 2       eaf2ea33-285b-4bf8-b350-e6e282cc3087  Pengguna Google
# 3       6bb6a348-d92f-4bda-92b5-ddedcbbe5f6a  Pengguna Google
# 4       c40a15e6-004c-455c-a14f-217579fe0c07  Pengguna Google
# ...                                      ...              ...
# 121494  9e9becc0-93e4-420a-a2dc-5b6a2d1d6601  Pengguna Google
# 121495  7f4d179d-bfe1-4c3b-986f-de1c72c152ff  Pengguna Google
# 121496  547b9764-d830-4a21-accf-9d0f5ee37dd3  Pengguna Google
# 121497  56dd7ab8-58ae-45a2-8c17-ab2414a77c78  Pengguna Google
# 121498  51af5002-10a7-48bf-80d0-610e387fdce6  Pengguna Google
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# 2       https://play-lh.googleusercontent.com/EGemoI2N...
# 3       https://play-lh.googleusercontent.com/EGemoI2N...
# 4       https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                   ...
# 121494  https://play-lh.googleusercontent.com/EGemoI2N...
# 121495  https://play-lh.googleusercontent.com/EGemoI2N...
# 121496  https://play-lh.googleusercontent.com/EGemoI2N...
# 121497  https://play-lh.googleusercontent.com/EGemoI2N...
# 121498  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       Awal pemakaian tidak ada gangguan tapi makin s...      3
# 1       Jaringan suka ilang,harus bolak balik mode pes...      1
# 2       Harga paket paling ramah di kantong dibanding ...      5
# 3       Kalau di bilang jaringannya mantap tapi agak n...      4
# 4       Kacau makin parah!!!, udah sering komplain jug...      1
# ...                                                   ...    ...
# 121494                                             mantab      5
# 121495                                             mantap      5
# 121496                                                Oke      5
# 121497                                             mantap      5
# 121498                                              bagus      5
#
#         thumbsUpCount reviewCreatedVersion                  at  \
# 0                  26               1.59.0 2024-11-27 11:42:00
# 1                 190               1.59.0 2024-11-27 22:27:49
# 2                 106               1.59.0 2024-11-28 21:30:02
# 3                   0               1.59.0 2024-12-02 18:31:36
# 4                  52               1.59.0 2024-11-29 19:21:15
# ...               ...                  ...                 ...
# 121494              0                  718 2021-10-22 09:31:34
# 121495              0                  718 2021-10-13 11:15:25
# 121496              0                  718 2021-10-14 23:51:23
# 121497              0                  718 2021-10-23 11:30:40
# 121498              0                  718 2021-10-16 13:27:36
#
#                                              replyContent           repliedAt  \
# 0       Dear, Kak Fazil. Maafin banget jadi bikin kamu... 2024-11-28 02:02:37
# 1       Hallo Kak Feri, maafin udah bikin ga nyaman. B... 2024-11-28 04:23:03
# 2       Halo, Kak Mahmud. Makasih banyak buat semua sa... 2024-11-29 08:08:26
# 3       Hi Kak, Makasih banyak ya buat feedback-nya, s... 2024-12-03 04:35:39
# 4       Hi, Kak. Maaf banget udah bikin ga nyaman. Unt... 2024-11-30 05:26:26
# ...                                                   ...                 ...
# 121494  Hi Kak, terima kasih banyak untuk feedback-nya... 2021-10-22 09:34:16
# 121495  Makasih buat feedback dan sarannya ya kak. Nin... 2021-10-13 11:17:49
# 121496  Hai Kak! Makasih banyak buat feedback dan sara... 2021-10-14 23:53:24
# 121497  Hai Kak. Makasih banyak buat feedbacknya ya. N... 2021-10-23 11:33:48
# 121498  Hai Kak. Makasih banyak buat feedbacknya ya. N... 2021-10-16 13:31:12
#
#        appVersion                                         text_clean  \
# 0          1.59.0  Awal pemakaian tidak ada gangguan tapi makin s...
# 1          1.59.0  Jaringan suka ilangharus bolak balik mode pesa...
# 2          1.59.0  Harga paket paling ramah di kantong dibanding ...
# 3          1.59.0  Kalau di bilang jaringannya mantap tapi agak n...
# 4          1.59.0  Kacau makin parah udah sering komplain juga se...
# ...           ...                                                ...
# 121494        718                                             mantab
# 121495        718                                             mantap
# 121496        718                                                Oke
# 121497        718                                             mantap
# 121498        718                                              bagus
#
#                                      text_casefoldingText  \
# 0       awal pemakaian tidak ada gangguan tapi makin s...
# 1       jaringan suka ilangharus bolak balik mode pesa...
# 2       harga paket paling ramah di kantong dibanding ...
# 3       kalau di bilang jaringannya mantap tapi agak n...
# 4       kacau makin parah udah sering komplain juga se...
# ...                                                   ...
# 121494                                             mantab
# 121495                                             mantap
# 121496                                                oke
# 121497                                             mantap
# 121498                                              bagus
#
#                                           text_slangwords  \
# 0       awal pemakaian tidak ada gangguan tapi makin s...
# 1       jaringan suka ilangharus bolak balik mode pesa...
# 2       harga paket paling ramah di kantong dibanding ...
# 3       kalau di bilang jaringannya mantap tapi agak n...
# 4       kacau makin parah udah sering komplain juga se...
# ...                                                   ...
# 121494                                             mantab
# 121495                                             mantap
# 121496                                                oke
# 121497                                             mantap
# 121498                                              bagus
#
#                                       text_tokenizingText  \
# 0       [awal, pemakaian, tidak, ada, gangguan, tapi, ...
# 1       [jaringan, suka, ilangharus, bolak, balik, mod...
# 2       [harga, paket, paling, ramah, di, kantong, dib...
# 3       [kalau, di, bilang, jaringannya, mantap, tapi,...
# 4       [kacau, makin, parah, udah, sering, komplain, ...
# ...                                                   ...
# 121494                                           [mantab]
# 121495                                           [mantap]
# 121496                                              [oke]
# 121497                                           [mantap]
# 121498                                            [bagus]
#
#                                             text_stopword  \
# 0       [pemakaian, gangguan, hilang, jaringan, aplika...
# 1       [jaringan, suka, ilangharus, bolak, mode, pesa...
# 2       [harga, paket, ramah, kantong, dibanding, prov...
# 3       [bilang, jaringannya, mantap, ngeleg, perbanya...
# 4       [kacau, parah, udah, komplain, udah, didenger,...
# ...                                                   ...
# 121494                                           [mantab]
# 121495                                           [mantap]
# 121496                                              [oke]
# 121497                                           [mantap]
# 121498                                            [bagus]
#
#                                                text_akhir
# 0       pemakaian gangguan hilang jaringan aplikasi to...
# 1       jaringan suka ilangharus bolak mode pesawat re...
# 2       harga paket ramah kantong dibanding provider k...
# 3       bilang jaringannya mantap ngeleg perbanyak dis...
# 4       kacau parah udah komplain udah didenger kompla...
# ...                                                   ...
# 121494                                             mantab
# 121495                                             mantap
# 121496                                                oke
# 121497                                             mantap
# 121498                                              bagus
#
# [95889 rows x 17 columns]

# %%
,
